# %%
# Perform my imports
import torch
from transformers import AutoTokenizer, BitsAndBytesConfig, AutoModelForCausalLM
import heapq
import json
import time
import random
import os
import re
import math
import pandas as pd
import sys
import numpy as np
from typing import Optional, List
from transformers import AutoTokenizer, LlamaForCausalLM, BitsAndBytesConfig, TrainingArguments
import json, csv
from sklearn.model_selection import train_test_split
from trl import SFTTrainer
from datasets import Dataset
from peft import LoraConfig

# Add the certs information
sys.path.append("..")
from CeRTS_beam_multi import *
from CeRTS_utils import *
sys.path.remove("..")

# Add some fine-tuning specific functions
from functions.generation_functions import *
from functions.dataset_creation_functions import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Initialization

# %%
# Specify models that we will test for (SFT models)
model_eval_list = ['models/llama-3.2-3b-instruct-SFT-val_test_10_15-merged']

# Specify base information needed for some model functions
variables = ['asthma', 'smoking', 'pneu', 'common_cold', 'pain', 'fever', 'antibiotics']
json_template = {
        "asthma": "yes|no",
        "smoking": "yes|no",
        "pneu": "yes|no",            
        "common_cold": "yes|no",
        "pain": "yes|no",
        "fever": "high|low|no",
        "antibiotics": "yes|no"}
features = json_template.keys()

# %% [markdown]
# # Get Test Val Data

# %%
# Load in model
df_val = pd.read_csv("clinical_data/validation.csv")

# Split into training and testing for temporary stuff 
train_df, test_df = train_test_split(df_val, test_size=0.2, random_state=42)
train_df.reset_index(drop=True, inplace = True)
test_df.reset_index(drop=True, inplace = True)

test_df = test_df[:20]

# %% [markdown]
# # Perform Actual Test Evaluation with CeRTS

# %%
# Iterate Through each model
for model_path in model_eval_list:
    
    # Load tokenizer and model 
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    model = AutoModelForCausalLM.from_pretrained(model_path, device_map="auto")
    
    # Specify Output location and see if it already exists 
    OUT_PATH = f'results_data/CeRTS_SimSUM_20_test_val_{model_path.split("/")[1]}.csv'
    
    # check if dataframe exists and create if not
    if os.path.exists(OUT_PATH):
        out_df = pd.read_csv(OUT_PATH)
    else:
        out_columns = ["compact_note", "asthma", "smoking", "pneu", "common_cold", "pain", "fever", "antibiotics", "LLM_asthma", "asthma_conf", "LLM_smoking", "smoking_conf", "LLM_pneu", "pneu_conf", "LLM_common_cold", "common_cold_conf", "LLM_pain", "pain_conf", "LLM_fever", "fever_conf", "LLM_antibiotics", "antibiotics_conf"]
        out_df = pd.DataFrame(columns = out_columns)
        out_df.to_csv(OUT_PATH)
    
    
    # Time Model 
    t1 = time.time()
    x = 0
    print('using file', OUT_PATH)
    
    # Open and save rows
    with open(OUT_PATH, "a", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        for _, row in test_df.iterrows():
            #print(row)
            #print(row['text'])
            #print('advanced')
            #print(row['advanced_text'])

            x+=1
            if x % 3 == 0:
                print(x, round((time.time()-t1)/60, 2), 'mins')

            
            compact_note,asthma,smoking,pneu,common_cold,pain,fever,antibiotics = row[['advanced_text','asthma','smoking','pneu','common_cold','pain','fever','antibiotics']]

            messages = gen_prompt(compact_note, features, json_template)
            #print(messages)
            answer_distributions = CeRTS_output_dist(messages, features, model, tokenizer, device, beam_width=5, max_steps=100)
            d_feature_conf = {}
            row_extract_conf = []
            for feature, answer_dist in zip(features, answer_distributions):
                # print(feature, answer_dist)
                response = answer_dist[0][0]
                # print(answer_dist[0])
                confidence = top_2_delta([answer_score_tuple[1] for answer_score_tuple in answer_dist])
                print('Feature:', feature, 'Response:', response, 'Confidence:', confidence)
                d_feature_conf[feature] = {'top_answer':response, 'confidence':confidence, 'dist':answer_dist}
                row_extract_conf.append(response)
                row_extract_conf.append(confidence)
                # print("-------------------")
            print("----------------------")
            combined_row = [x] + [compact_note,asthma,smoking,pneu,common_cold,pain,fever,antibiotics] + row_extract_conf

            writer.writerow(combined_row)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# using file results_data/CeRTS_SimSUM_20_test_val_llama-3.2-3b-instruct-SFT-val_test_10_15-merged.csv
# Feature: asthma Response: no Confidence: 0.9499186162960178
# Feature: smoking Response: no Confidence: 0.17943028487493867
# Feature: pneu Response: no Confidence: 0.820056607160318
# Feature: common_cold Response: no Confidence: 0.35100935368582575
# Feature: pain Response: no Confidence: 0.8190578968786132
# Feature: fever Response: no Confidence: 0.693214919588693
# Feature: antibiotics Response: no Confidence: 0.22623851967778685
# ----------------------
# Feature: asthma Response: no Confidence: 0.9516556080930427
# Feature: smoking Response: no Confidence: 0.7675254541782468
# Feature: pneu Response: no Confidence: 0.7934590399754273
# Feature: common_cold Response: no Confidence: 0.8096149388717437
# Feature: pain Response: no Confidence: 0.6057759298623747
# Feature: fever Response: no Confidence: 0.8305814542210684
# Feature: antibiotics Response: no Confidence: 0.7034691055931392
# ----------------------
# 3 0.93 mins
# Feature: asthma Response: no Confidence: 0.9111156226811921
# Feature: smoking Response: no Confidence: 0.734324841199268
# Feature: pneu Response: no Confidence: 0.8140423268480795
# Feature: common_cold Response: no Confidence: 0.6341596849001433
# Feature: pain Response: yes Confidence: 0.044852524885740985
# Feature: fever Response: no Confidence: 0.6399888789306327
# Feature: antibiotics Response: no Confidence: 0.4733936838774345
# ----------------------
# Feature: asthma Response: no Confidence: 0.9534388456537449
# Feature: smoking Response: no Confidence: 0.8508761055413648
# Feature: pneu Response: no Confidence: 0.8219061085898998
# Feature: common_cold Response: no Confidence: 0.8243566110561654
# Feature: pain Response: no Confidence: 0.7738606475693468
# Feature: fever Response: no Confidence: 0.7370253158205303
# Feature: antibiotics Response: no Confidence: 0.6418681250551742
# ----------------------
# Feature: asthma Response: no Confidence: 0.9379607157647806
# Feature: smoking Response: no Confidence: 0.829300469434806
# Feature: pneu Response: no Confidence: 0.8470640295400953
# Feature: common_cold Response: no Confidence: 0.42392119079215296
# Feature: pain Response: no Confidence: 0.8653301168687733
# Feature: fever Response: no Confidence: 0.8833476221275253
# Feature: antibiotics Response: no Confidence: 0.6591298073296267
# ----------------------
# 6 2.32 mins
# Feature: asthma Response: no Confidence: 0.9284300497473512
# Feature: smoking Response: no Confidence: 0.8349364733748138
# Feature: pneu Response: no Confidence: 0.8153647736423528
# Feature: fever Response: no Confidence: 0.7953706875517484
# Feature: antibiotics Response: no Confidence: 0.4506891563350668
# ----------------------
# Feature: asthma Response: no Confidence: 0.8970146244258347
# Feature: smoking Response: no Confidence: 0.7532133663144599
# Feature: pneu Response: no Confidence: 0.7301170297673899
# Feature: common_cold Response: no Confidence: 0.355180780892122
# Feature: pain Response: no Confidence: 0.8102591267958972
# Feature: fever Response: no Confidence: 0.837803925040523
# Feature: antibiotics Response: no Confidence: 0.49168574167181933
# ----------------------
# 15 6.4 mins
# Feature: asthma Response: yes Confidence: 0.7329370177353784
# Feature: smoking Response: no Confidence: 0.7872047014460261
# Feature: pneu Response: no Confidence: 0.8422529800912482
# Feature: common_cold Response: yes Confidence: 0.146796145929329
# Feature: pain Response: no Confidence: 0.9269569256996165
# Feature: fever Response: high Confidence: 0.6220949049341585
# Feature: antibiotics Response: no Confidence: 0.5165523211501853
# ----------------------
# Feature: asthma Response: no Confidence: 0.9447610299643293
# Feature: smoking Response: no Confidence: 0.796993030281288
# Feature: pneu Response: no Confidence: 0.7201099494729064
# Feature: common_cold Response: no Confidence: 0.8207563989629622
# Feature: pain Response: no Confidence: 0.8616877426930452
# Feature: fever Response: no Confidence: 0.9039594353774545
# Feature: antibiotics Response: no Confidence: 0.6142091587979384
# ----------------------
# Feature: asthma Response: no Confidence: 0.9385248999132337
# Feature: smoking Response: yes Confidence: 0.9028641760556962
# Feature: pneu Response: no Confidence: 0.8093459312628064
# Feature: common_cold Response: yes Confidence: 0.35649951178858263
# Feature: pain Response: no Confidence: 0.8560692807882486
# Feature: fever Response: no Confidence: 0.6713225607192196
# Feature: antibiotics Response: no Confidence: 0.5126904483732306
# ----------------------
# 18 7.7 mins
# Feature: asthma Response: no Confidence: 0.9557234623637811
# Feature: smoking Response: no Confidence: 0.7775139345258102
# Feature: pneu Response: no Confidence: 0.8077899985922109
# Feature: common_cold Response: no Confidence: 0.6574159451758916
# Feature: pain Response: no Confidence: 0.8468079273907594
# Feature: fever Response: no Confidence: 0.8961673035409687
# Feature: antibiotics Response: no Confidence: 0.4829497861303921
# ----------------------
# Feature: asthma Response: no Confidence: 0.9280767752301586
# Feature: smoking Response: yes Confidence: 0.3089288968803521
# Feature: pneu Response: no Confidence: 0.8059757346470925
# Feature: common_cold Response: no Confidence: 0.7233212551189062
# Feature: pain Response: no Confidence: 0.7304082474929603
# Feature: fever Response: no Confidence: 0.8088055117253407
# Feature: antibiotics Response: no Confidence: 0.45313444567710237
# ----------------------
# Feature: asthma Response: yes Confidence: 0.8505033866975904
# Feature: smoking Response: no Confidence: 0.8552834336182027
# Feature: pneu Response: no Confidence: 0.8606369917076406
# Feature: common_cold Response: no Confidence: 0.8812349040641115
# Feature: pain Response: no Confidence: 0.8599104031152848
# Feature: fever Response: no Confidence: 0.8493283666733407
# Feature: antibiotics Response: no Confidence: 0.6345660406971841
# ----------------------
